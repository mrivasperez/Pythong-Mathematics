# %% [markdown]
# # Arithmetic
# Addition, subtraction, multiplication, and divison.

# %% [markdown]
# ### Addition

# %%
# You can use Python as a calculator, by simply running basic math problems.
4 + 5
# Out:
# 9

# %%
4 + 1 + 5
# Out:
# 10

# %% [markdown]
# ### Subtraction

# %%
5-3
# Out:
# 2

# %% [markdown]
# ### Multiplication

# %%
5 * 2
# Out:
# 10

# %% [markdown]
# ### Division

# %%
3 / 4
# Out:
# 0.75

# %% [markdown]
# ### Multiple Operators
# Uses the order of operations!

# %%
3 * 3 + 1 - 5
# Out:
# 5

# %% [markdown]
# It is often very helpful to use parenthesis to separate the numbers visually and help you establish the order of operations for Python interpreter.

# %%
((3 * 3)* 2) / 2
# Out:
# 9.0

# %%
5 - ((2/4) * (3/5))
# Out:
# 4.7

# %%
(4 - 5)/(3 + (5 * 6))
# Out:
# -0.030303030303030304
