# %% [markdown]
# # Using variable in place of numbers
# A variable can be placeholder for data such as numbers, strings, booleans, etc. When using python for mathematics, this is very helpful because it lets you use variables in place of numbers within equations.

# %%
x = 10

# %%
x
# Out:
# 10

# %%
x - 2
# Out:
# 8

# %%
x = x - 2 * 5

# %%
x
# Out:
# 0

# %%
#If you use an undefined variable, you get an error
x = 10
y = 20
x + y * z
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-921786be6cc5> in <module>
#       1 x = 10
#       2 y = 20
# ----> 3 x + y * z
#
# NameError: name 'z' is not defined

# %%
x = 10
y = 20
z = 31

# %%
x + (y * z)
# Out:
# 630

# %%
mikeAge = 10
spikeAge = 34
mikeAge + spikeAge
# Out:
# 44

# %%
print(x + x + z)
# Out:
# 51

# %%
x = 7
y = -2
z = 5

print((3*x)*(4 + y))
print(-y - ((x+4))
# Out:
# 42
